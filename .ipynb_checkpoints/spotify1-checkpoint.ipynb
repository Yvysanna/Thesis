# %%
import pandas as pd
from collections import Counter
from functional import get_data, process, clean_df, clean

# %% [markdown]
# ### Preparation:
# Reading files</br>
# Cleaning data

# %%
full_male, full_female = get_data()

# %%
# Creating subsets from the data to work with
male, female = process(full_male), process(full_female)

# %%
# Clean all data by removing trailing whitespaces and lowercasing all letters
female = clean_df(female.copy())
male = clean_df(male.copy())

# %% [markdown]
# Now that data is clean, textual analysis can begin

# %% [markdown]
# ### Similarities:
# Find which playlists both users got recommended

# %%
# Check which playlists both users have in common
similar_playlists = male[male['playlist name'].isin(female['playlist name'])]
similar_playlists = similar_playlists[similar_playlists.type == 'playlist']
#similar_playlists

# %%
len(similar_playlists)
# Out:
# 2067

# %%
diff = male[~male['playlist name'].isin(female['playlist name'])]
diff = diff[diff.type == 'playlist']
len(diff)
# Out:
# 1323

# %%
m_playlist = male[male.type == 'playlist']
f_playlist = female[female.type == 'playlist']

# %%
# Looking for the most common recommended playlists per user
m = dict(Counter(m_playlist['playlist name']).most_common())
mdf = pd.DataFrame({'male': m.keys(), 'count': m.values()})

f = dict(Counter(f_playlist['playlist name']).most_common())
fdf = pd.DataFrame({'female': f.keys(), 'count': f.values()})

#display(mdf.head(20), fdf.head(20))

# %%
m.keys()
# Out:
# dict_keys(['je moerstaal', 't koffiehuis', 'fresh pop', 'all out 2010s', 'stay tuned', 'all out 2000s', 'beste van nl', 'chill hits', 'soft pop hits', 'rock classics', 'big on the internet', 'happy tunes', 'afro hits', 'hit rewind', 'all out 90s', 'all out 80s', 'daily drive', 'mood booster', 'jazz classics', 'songs to sing in the shower', '360 dance', 'platinum hits', 'global x', 'summer 22', 'fresh flows', 'throwback party', 'new music friday', 'daily mix 1', 'daily mix 2', 'daily mix 3', 'happy mix', 'feeling good feeling great', 'best of the decade for you', 'daily mix 6', 'top hits workout', 'taylor swift radio', 'daily mix 4', 'daily mix 5', 'moody mix', 'reggaeton mix', 'pop mix', 'baila reggaeton', 'easy 80s', 'rock mix', 'rapcaviar', 'hot new dance', 'pink floyd radio', 'soft rock', 'bad bunny radio', 'this is taylor swift', 'viva latino', 'just hits', '70s mix', '2010s mix', 'hot country', 'woordenschat', 'daily lift', 'bts radio', 'vibes', 'made in nl', '70s rock anthems', 'i love my 90s hiphop', 'classical new releases', 'desi hits', 'afropop', 'funk hits', 'summer hits of the 10s', 'la vida loca', 'african heart', 'radar global', 'radar canada', 'radar us', 'pop rising', 'afrobeats mix', 'most necessary', 'kpop on', 'broken heart', 'this is bad bunny', 'this is bts', 'its lit', 'genz nostalie', 'fresh hits', 'dopamine', 'my life is a movie', 'this is racoon', 'this is nick  simon', 'this is andr hazes', 'songs to scream in the car', 'bbe', 'life sucks', 'african heat', 'best new artist 2022', 'rap uk', 'beste van woordenschat', 'pull up hits', 'party tunes', 'the locker', 'lorem', 'this is pink floyd', 'pure rock  roll', 'classic acoustic', 'positive vibes', 'peaceful piano', 'lofi beats', 'guilty pleasures', 'dj vu', 'the 80s all lined up', 'kclub party', 'latin pop classics', 'easy on sunday', 'happy beats', 'factor happy', 'beautiful day', 'sad covers', 'a walk alone', 'the midnight hour', 'sad beats', 'sad classical', 'dark  stormy', 'tender', '80s beste nltalig', '60s beste nltalig', '70s beste nltalig', 'dire straits mix', 'mellow bars', 'goosebumps', 'legendary', 'beast mode', 'motivation mix', 'fun run', 'power hour', 'run this town', 'feelin myself', 'you  me', 'calm before the storm', 'this is tabitha', 'de jeugd', 'comfort zone', 'power workout', 'chill mode on', 'preparty mood', 'this is guus meeuwis', 'cardio', '80s rock anthems', '00s rock anthems', '90s rock anthems', 'full volume', 'kink 1500', 'internet people', 'mega hit mix', 'homework vibes', 'kpop mix', 'harry styles radio', 'workout', 'confidence boost', '00s beste nltalig', '90s beste nltalig', '10s beste nltalig', '80s soft rock', 'alternative all lined up', 'classic afropop', 'rainy day jazz', 'karakter', 'easy on saturday', 'camila cabello mix', 'women of pop', '10s love songs', 'bones radio', 'numb little bug radio', 'fingers crossed radio', 'i love my 2000s rb', 'fast pop run', 'chilled rb', 'chill vibes', 'chillin on a dirty road', 'easy 00s', 'tear drop', 'soft 10s', 'time capsule', 'liked songs', 'taylor swift mix', 'bad bunny mix', 'bts mix', 'this is nielson', 'this is blof', 'best rap songs of 2017', 'new music friday nl', 'rb mix', 'grime mix', 'all out 70s', 'trowback party', 'lauren spencersmith mix', 'harry styles mix', 'chill mix', 'vanavond uit mn bol radio', 'nothing else matters radio', 'when youre gone radio', 'shes all i wanna be radio', 'infinity radio', 'energy booster hiphop', 'dance party', 'deep dark indie', 'charlie puth radio', 'pink floyd mix', 'top workout hits', 'doja cat mix', 'the party hits of the 2010s', 'idgaf with blackbear radio', 'middle of the night radio', 'discover weekly', 'classical afropop', 'todays top hits', 'workout hiphop', '2000s mix', '90s mix', 'deep house relax', 'jazz vibes', 'chillout lounge', 'coffee table jazz', 'born to run', 'raised on rock', 'on screen guitar', 'new alternative', 'girls night', 'pop remix', 'tropical house', 'best hiphop songs of 2020', 'jack harlow radio', 'music o ...

# %%
simm = dict()

p = similar_playlists['playlist name'].astype(str)
for key, value in m.items():
    if key in p:
        simm[key] = value
        
len(simm)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 0

# %% [markdown]
# ### Looking for the difference between how often male vs female user received certain playlists

# %%
most_common_playlists = {
    'male': dict(Counter(m_playlist['playlist name']).most_common()), 
    'female': dict(Counter(f_playlist['playlist name']).most_common())
}

# Fill all playlists only one user gets recommended
new = pd.DataFrame(most_common_playlists).fillna(0)

# Get difference
new['diff'] = abs(new['male'] - new['female'])

# Sort
new.sort_values(by = 'diff', ascending=False, inplace=True)
new.head(60)
# Out:
#                              male  female  diff
# lofi beats                    6.0    64.0  58.0
# Top Songs Global              2.0    58.0  56.0
# Top 50 Global                 2.0    57.0  55.0
# Instrumental Study            1.0    54.0  53.0
# Je Moerstaal                 79.0    31.0  48.0
# Songs to Sing in the Shower  30.0    74.0  44.0
# Today's Top Hits              0.0    43.0  43.0
# Top 50 Netherlands            2.0    40.0  38.0
# Peaceful Piano                5.0    39.0  34.0
# Karaoke Duets                 1.0    32.0  31.0
# Cardio                        0.0    31.0  31.0
# Top Songs Nederland           0.0    31.0  31.0
# Mood Booster                 31.0     0.0  31.0
# Viral 50 Global               1.0    32.0  31.0
# Viral 50 Netherlands          1.0    32.0  31.0
# Beste van NL                 37.0     6.0  31.0
# Pop Sauce                     3.0    34.0  31.0
# Top Songs Netherlands         1.0    31.0  30.0
# Vibes                         6.0    36.0  30.0
# Techno Bunker                 0.0    30.0  30.0
# Life Sucks                   12.0    42.0  30.0
# Beste van NL                  0.0    29.0  29.0
# Sing-along: 90's to Now       0.0    29.0  29.0
# Jazz Classics                30.0     1.0  29.0
# Classic Pop Picks             0.0    27.0  27.0
# Mega Hit Mix                  0.0    27.0  27.0
# Are & Be                      0.0    27.0  27.0
# Top 2000                      2.0    29.0  27.0
# Platinum Hits                30.0     4.0  26.0
# Happy Mix                    26.0     0.0  26.0
# Power Hour                    0.0    25.0  25.0
# Disney Hits                   0.0    25.0  25.0
# Acoustic Favorites            1.0    26.0  25.0
# Run This Town                 0.0    25.0  25.0
# Daily Drive                  31.0     6.0  25.0
# Power Workout                 0.0    24.0  24.0
# Workout                       0.0    24.0  24.0
# Beast Mode                    0.0    24.0  24.0
# Motivation Mix                0.0    24.0  24.0
# Viral Hits NL                 0.0    24.0  24.0
# Pop Mix                      23.0     0.0  23.0
# Soft Pop Hits                31.0     8.0  23.0
# Feeling Good Feeling Great   26.0     3.0  23.0
# Hot Hits NL                   0.0    23.0  23.0
# Summer '22                   25.0    48.0  23.0
# Moody Mix                    23.0     0.0  23.0
# Reggaeton Mix                23.0     0.0  23.0
# big on the Internet          23.0     0.0  23.0
# Fresh Flows                  29.0     7.0  22.0
# New Music Friday NL           5.0    27.0  22.0
# Rock Mix                     22.0     0.0  22.0
# Fun Run                      10.0    31.0  21.0
# 360 Dance                    30.0     9.0  21.0
# Daily Mix 3                  27.0     6.0  21.0
# Daily Mix 2                  27.0     6.0  21.0
# Daily Mix 1                  27.0     6.0  21.0
# K-Club Party                 11.0    31.0  20.0
# Hit Rewind                    0.0    20.0  20.0
# This is Taylor Swift         20.0     0.0  20.0
# Hot Country                  20.0     0.0  20.0

# %% [markdown]
# ### Differences in playlist recommendations between both users

# %%
# Looking for top playlists both users were recommended that the other user was not
male_count = dict(Counter(m_playlist['playlist name'][~m_playlist['playlist name'].isin(f_playlist['playlist name'])]).most_common())
female_count = dict(Counter(f_playlist['playlist name'][~f_playlist['playlist name'].isin(m_playlist['playlist name'])]).most_common())

display(
pd.DataFrame({'male': male_count.keys(), 'count' : male_count.values()}).head(20),
pd.DataFrame({'female': female_count.keys(), 'count' : female_count.values()}).head(20)
)
# Out:
#                       male  count
# 0      big on the internet     35
# 1             mood booster     31
# 2                happy mix     26
# 3                moody mix     23
# 4            reggaeton mix     23
# 5                  pop mix     23
# 6                 rock mix     22
# 7                soft rock     20
# 8     this is taylor swift     20
# 9                  70s mix     20
# 10               2010s mix     20
# 11             hot country     20
# 12              made in nl     18
# 13        70s rock anthems     18
# 14               desi hits     17
# 15                 afropop     17
# 16               funk hits     17
# 17  summer hits of the 10s     16
# 18           african heart     16
# 19            radar global     16
#                      female  count
# 0       top songs nederland     31
# 1             viral hits nl     28
# 2         classic pop picks     27
# 3                   are  be     27
# 4               hot hits nl     25
# 5        zomerhits 20102020     19
# 6       homework motivation     15
# 7               singled out     15
# 8           all new all now     15
# 9           sing along kpop     14
# 10         top hits of 2018     14
# 11                 ckay mix     14
# 12         top hits of 2017     13
# 13          yoga  mediation     13
# 14    sing along indie hits     13
# 15            workout beats     12
# 16              young  free     12
# 17  piano in the background     11
# 18        camila cabellomix     10
# 19          jack harlow mix      9

# %% [markdown]
# Tagging times after morning, afternoon and evening

# %%
copy = male.copy()
copy['time'] = copy.time.astype(str).apply(lambda x: int(x[:2]))

# Translate the times to dayphases
for i, time in copy.time.iteritems():
    if time < 12:
        copy.iloc[i] = 'morning'
    elif time >=12<19:
        copy.iloc[i] = 'afternoon'
    else:
        copy.iloc[i] = 'evening'

# %%
male[copy['time'] == 'morning']
# Out:
#             day      time                hub name       playlist name  \
# 0    2022-04-14  10:00:00      to get you started    taylor swift mix
# 1    2022-04-14  10:00:00      to get you started       bad bunny mix
# 2    2022-04-14  10:00:00      to get you started             bts mix
# 3    2022-04-14  10:00:00      try something else            hot hits
# 4    2022-04-14  10:00:00      try something else  top 50 netherlands
# ...         ...       ...                     ...                 ...
# 3757 2022-04-20  09:40:00      made for male name         daily mix 6
# 3758 2022-04-20  09:40:00      made for male name         daily drive
# 3759 2022-04-20  09:40:00  new and rising artists        radar global
# 3760 2022-04-20  09:40:00  new and rising artists        radar canada
# 3761 2022-04-20  09:40:00  new and rising artists            radar us
#
#           type
# 0     playlist
# 1     playlist
# 2     playlist
# 3     playlist
# 4     playlist
# ...        ...
# 3757  playlist
# 3758  playlist
# 3759  playlist
# 3760  playlist
# 3761  playlist
#
# [989 rows x 5 columns]

# %%
# Calculating how many times the woman received dinner hubs
Counter(female['playlist name'][female['hub name'] == 'dinner'])
# Out:
# Counter({'dinner with friends': 5,
#          'dinner music': 5,
#          'feel good dinner': 5,
#          'kitchen swagger': 5,
#          'latin dinner': 5,
#          'jazzy dinner': 5,
#          'bossa nova dinner': 5,
#          'the perfect italian dinner': 4,
#          'dinner lounge': 5,
#          'dinner entre amis': 5})

# %%
# Counting workout playlists
display(pd.DataFrame(Counter(female['playlist name'][female['hub name'] == 'workout']).most_common()))
display(pd.DataFrame(Counter(male['playlist name'][male['hub name'] == 'workout']).most_common()))
# Out:
#                    0   1
# 0         power hour  32
# 1   top hits workout  31
# 2         beast mode  31
# 3            fun run  31
# 4     motivation mix  31
# 5            workout  31
# 6             cardio  31
# 7      run this town  31
# 8      power workout  29
# 9    yoga  mediation  13
# 10     workout beats  11
# 11   running x remix   5
# 12  yoga  meditation   2
# 13      latin cardio   1
# 14       zumba beats   1
# 15    workout hiphop   1
#                    0   1
# 0     motivation mix  10
# 1            fun run  10
# 2         power hour  10
# 3      run this town  10
# 4   top hits workout   9
# 5         beast mode   9
# 6      power workout   9
# 7             cardio   9
# 8            workout   8
# 9       fast pop run   6
# 10    workout hiphop   3
# 11   running x remix   1
# 12      latin cardio   1

# %%
print(dict(Counter(male['playlist name'][male['hub name'] == 'mood']).most_common()).keys(),'\n',
dict(Counter(female['playlist name'][female['hub name'] == 'mood']).most_common()).keys())
# Out:
# dict_keys(['t koffiehuis', 'you  me', 'calm before the storm', 'easy on sunday', 'feelin myself', 'feeling good feeling great', 'happy tunes', 'chill hits', 'peaceful piano', 'life sucks', 'lofi beats', 'songs to sing in the shower', 'techno bunker', 'broken heart', 'latin pop classics'])
#  dict_keys(['life sucks', 'broken heart', 'peaceful piano', 'instrumental study', 'vibes', 't koffiehuis', 'happy tunes', 'chill hits', 'songs to sing in the shower', 'lofi beats', 'easy 80s', 'techno bunker', 'all the feels', 'intense studying', 'soft pop hits'])

# %% [markdown]
# Differences between how often female vs male received lo-fi beats and life sucks

# %%
print(len(male[male['playlist name'] =='life sucks']), len(female[female['playlist name'] =='life sucks']))
print(len(male[male['playlist name'] =='lofi beats']), len(female[female['playlist name'] =='lofi beats']))
# Out:
# 12 42
# 11 71

# %% [markdown]
# Checking for hub names hinting towards sentiment playlists, ignoring 'more like' or similar playlists as they are targeted towards music discovery for artists, similar playlists or algorithmically generated, sentiment neutral playlists

# %%
female_hubs = list(f_playlist['hub name'])
female_hubs = [e for e in female_hubs if not e.startswith('more like') and not e.startswith('recommended')]
set(female_hubs)
# Out:
# {'artists you like',
#  'chill',
#  'dinner',
#  'featured charts',
#  'fresh new music',
#  'instrumental',
#  'made for female name',
#  'mood',
#  'party',
#  'singalong',
#  'suggested artists',
#  'throwback',
#  'to get you started',
#  'todays biggest hits',
#  'try something else',
#  'workout'}

# %%
male_hubs = list(m_playlist['hub name'])
male_hubs = [e for e in male_hubs 
if not e.startswith('more') and 
not e.startswith('recommended') and 
not e.startswith('for fans') and 
not e.startswith('discover') and
not e.endswith('name') and
not e.endswith('albums') and
not e.endswith('charts') and
not e.endswith('artists') and

# no personalized playlists
'you' not in e]

Counter(male_hubs).most_common()
# Out:
# [('throwback', 274),
#  ('blijf op de hoogte', 266),
#  ('global cultures on the main stage', 171),
#  ('fresh new music', 167),
#  ('dream playlist rotation', 132),
#  ('dutch language pop', 131),
#  ('hip hop', 117),
#  ('sad songs', 110),
#  ('chill', 98),
#  ('pop', 97),
#  ('workout', 93),
#  ('happy', 86),
#  ('rock', 86),
#  ('mood', 66),
#  ('singalong', 65),
#  ('party', 27),
#  ('the best dance playlists', 10),
#  ('playlists celebrating women', 10),
#  ('love', 10),
#  ('current hits and the 10s', 10),
#  ('women of pop', 10),
#  ('try something else', 9),
#  ('todays biggest hits', 9),
#  ('instrumental', 8),
#  ('sad love', 8),
#  ('celebrating 5 years of american teen', 2),
#  ('weeknd vibes', 2)]

# %% [markdown]
# Activity or mood related playlists extracted from here are
# 'chill,', 'dinner,', 'instrumental,', 'mood,', 'party,', 'singalong,', 'throwback,', 'workout'

# %%
# looking for mood playlists
Counter(f_playlist['playlist name'][f_playlist['hub name'].isin(['mood','vibes'])]).most_common()
# Out:
# [('life sucks', 31),
#  ('broken heart', 31),
#  ('peaceful piano', 28),
#  ('instrumental study', 28),
#  ('vibes', 15),
#  ('t koffiehuis', 14),
#  ('happy tunes', 14),
#  ('chill hits', 14),
#  ('songs to sing in the shower', 14),
#  ('lofi beats', 13),
#  ('easy 80s', 4),
#  ('techno bunker', 1),
#  ('all the feels', 1),
#  ('intense studying', 1),
#  ('soft pop hits', 1)]

# %% [markdown]
# Checking how often the user was recommended certain mood playlists

# %%
f_playlist['day'][f_playlist['playlist name'] == 'life sucks']
set(f_playlist['day'][f_playlist['playlist name'] == 'songs to sing in the shower'])
# Out:
# {Timestamp('2022-04-14 00:00:00'),
#  Timestamp('2022-04-15 00:00:00'),
#  Timestamp('2022-04-16 00:00:00'),
#  Timestamp('2022-04-17 00:00:00'),
#  Timestamp('2022-04-18 00:00:00'),
#  Timestamp('2022-04-19 00:00:00'),
#  Timestamp('2022-04-20 00:00:00')}

# %%
# Male mood playlists
Counter(male['playlist name'][male['hub name'].isin(['mood','vibes','sad songs','sad vibes','happy'])]).most_common()
# Out:
# [('feeling good feeling great', 18),
#  ('life sucks', 12),
#  ('broken heart', 12),
#  ('happy beats', 11),
#  ('factor happy', 11),
#  ('vibes', 11),
#  ('beautiful day', 11),
#  ('a walk alone', 11),
#  ('the midnight hour', 11),
#  ('sad beats', 11),
#  ('sad classical', 11),
#  ('dark  stormy', 11),
#  ('tender', 11),
#  ('t koffiehuis', 10),
#  ('you  me', 10),
#  ('calm before the storm', 10),
#  ('sad covers', 10),
#  ('songs to sing in the shower', 9),
#  ('easy on sunday', 9),
#  ('feelin myself', 9),
#  ('preparty mood', 9),
#  ('confidence boost', 8),
#  ('rainy day jazz', 7),
#  ('happy tunes', 6),
#  ('deep dark indie', 4),
#  ('je moerstaal', 3),
#  ('classic road trip songs', 2),
#  ('chill hits', 1),
#  ('peaceful piano', 1),
#  ('lofi beats', 1),
#  ('techno bunker', 1),
#  ('melancholy', 1),
#  ('latin pop classics', 1)]

# %% [markdown]
# ### Workout playlists

# %%
pd.DataFrame(Counter(male['playlist name'][male['hub name'].isin(['workout'])]).most_common())
# Out:
#                    0   1
# 0     motivation mix  10
# 1            fun run  10
# 2         power hour  10
# 3      run this town  10
# 4   top hits workout   9
# 5         beast mode   9
# 6      power workout   9
# 7             cardio   9
# 8            workout   8
# 9       fast pop run   6
# 10    workout hiphop   3
# 11   running x remix   1
# 12      latin cardio   1

# %%
pd.DataFrame(Counter(female['playlist name'][female['hub name'].isin(['workout'])]).most_common())
# Out:
#                    0   1
# 0         power hour  32
# 1   top hits workout  31
# 2         beast mode  31
# 3            fun run  31
# 4     motivation mix  31
# 5            workout  31
# 6             cardio  31
# 7      run this town  31
# 8      power workout  29
# 9    yoga  mediation  13
# 10     workout beats  11
# 11   running x remix   5
# 12  yoga  meditation   2
# 13      latin cardio   1
# 14       zumba beats   1
# 15    workout hiphop   1
